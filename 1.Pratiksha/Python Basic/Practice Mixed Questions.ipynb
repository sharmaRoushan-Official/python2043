# %% [markdown]
# # String Questions
# # 1.Write a Python program to print a string entered by the user

# %%
s =input("Enter the String:")
print(s)
# Out:
# Enter the String: Pratiksha
# Pratiksha

# %% [markdown]
# # 2.Write a program to find the length of a string.

# %%
print(len(s))
# Out:
# 9

# %% [markdown]
# # 3.Write a program to convert a string to uppercase.

# %%
print(s.upper())
# Out:
# PRATIKSHA

# %% [markdown]
# # 4. Write a program to convert a string to lowercase.

# %%
print(s.lower())
# Out:
# pratiksha

# %% [markdown]
# # 5.Write a program to count the number of vowels in a string

# %%
s="Pratiksha"
count =0

for s in "aeiou":
    count=count+1
print(count)
# Out:
# 5

# %% [markdown]
# # 6.Write a program to reverse a string

# %%
s ="Patil"
print(s[::-1])
# Out:
# litaP

# %% [markdown]
# # 7.Write a program to check whether a given string is a palindrome

# %%
s="madam"
s1=s[::-1]

if s==s1:
  print("given string is palindrome")
else:
  print("given string is not palindrome")
# Out:
# given string is palindrome

# %% [markdown]
# # 8.Write a program to count the occurrence of a specific character in a string

# %%
s="Pratiksha"
count=0

for s in "P":
    count=count+1
print(count)
# Out:
# 1

# %% [markdown]
# # 9.Write a program to replace a word in a string with another word

# %%
s="Hello World"
print(s.replace("World","Pratiksha"))
# Out:
# Hello Pratiksha

# %% [markdown]
# # 10.Write a program to split a sentence into a list of words

# %%
sentence ="I am Pratiksha"
print(sentence.split())
# Out:
# ['I', 'am', 'Pratiksha']

# %% [markdown]
# # List Questions
#
# # 1.Create a list of 5 numbers and print it

# %%
list=[1,2,3,4,5]
list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # 2.Write a program to find the length of a list

# %%
list=[1,2,3,4,5]
print(list)
print(len(list))
# Out:
# [1, 2, 3, 4, 5]
# 5

# %% [markdown]
# # 3.Write a program to add an element to the end of a list

# %%
list=[1,2,3,4,5]
list.append("Pratiksha")
print(list)
# Out:
# [1, 2, 3, 4, 5, 'Pratiksha']

# %% [markdown]
# # 4.Write a program to insert an element at a specific position in a list

# %%
list
# Out:
# [1, 2, 3, 4, 5, 'Pratiksha']

# %%
list.insert(2,"Patil")
print(list)
# Out:
# [1, 2, 'Patil', 3, 4, 5, 'Pratiksha']

# %% [markdown]
# # 5.Write a program to remove an element from a list

# %%
list.remove("Patil")

# %%
list
# Out:
# [1, 2, 3, 4, 5, 'Pratiksha']

# %% [markdown]
# # 6.Write a program to find the largest number in a list

# %%
list=[1,2,3,4,5]
print(max(list))
# Out:
# 5

# %% [markdown]
# # 7.Write a program to find the smallest number in a list

# %%
print(min(list))
# Out:
# 1

# %% [markdown]
# # 8.Write a program to sort a list in ascending order

# %%
list=[1,2,3,10,5,8,-2,-9,2.6,90]
print(sorted(list))
# Out:
# [-9, -2, 1, 2, 2.6, 3, 5, 8, 10, 90]

# %% [markdown]
# # 9.Write a program to count how many times a specific element appears in a list

# %%
list=[1,2,3,4,5,5,5,6,7,8,9]
print(list.count(5))
# Out:
# 3

# %% [markdown]
# # 10.Write a program to reverse a list

# %%
list=[1,2,3,4,5,5,5,6,7,8,9]
list[::-1]
# Out:
# [9, 8, 7, 6, 5, 5, 5, 4, 3, 2, 1]

# %% [markdown]
# # Tuple Questions
#
# # 1.Create a tuple containing 5 different values and print it

# %%
tuple=(10,20,30,40,50)
print(tuple)
# Out:
# (10, 20, 30, 40, 50)

# %% [markdown]
# # 2.Write a program to find the length of a tuple

# %%
print(len(tuple))
# Out:
# 5

# %% [markdown]
# # 3.Write a program to access the third element of a tuple

# %%
tuple=(10,20,30,40,50)
print(tuple[2])
# Out:
# 30

# %% [markdown]
# # 4.Write a program to check whether an element exists in a tuple

# %%
tuple=(10,20,30,40,50)
print(10 in tuple)
# Out:
# True

# %% [markdown]
# # 5.Write a program to count the occurrence of a specific value in a tuple

# %%
tuple=(10,20,30,30,30,40,50,60,70)
print(tuple.count(30))
# Out:
# 3

# %% [markdown]
# # 6.Write a program to find the index of a given element in a tuple

# %%
tuple=(10,20,30,30,30,40,50,60,70)
print(tuple.index(30))
# Out:
# 2

# %% [markdown]
# # 7.Write a program to concatenate two tuples.

# %%
t1=(10,20,30)
t2=(40,50,60)

print(t1)
print(t2)

print("t3:",t1+t2)
# Out:
# (10, 20, 30)
# (40, 50, 60)
# t3: (10, 20, 30, 40, 50, 60)

# %% [markdown]
# # 8.Write a program to convert a tuple into a list

# %%
t=(10,20,30,40,50)
print("Tuple",t)

l1=list(t)
print("List:",l1)
# Out:
# Tuple (10, 20, 30, 40, 50)
# List: [10, 20, 30, 40, 50]

# %% [markdown]
# # 9.Write a program to find the maximum and minimum values in a tuple.

# %%
t = (10,20,30,40,50,60)
print(max(t))
print(min(t))
# Out:
# 60
# 10

# %% [markdown]
# # 10. Write a program to iterate through all elements of a tuple and print them.

# %%
t = (1,2,3,4,5)

for i in t:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
