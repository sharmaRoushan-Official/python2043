# %% [markdown]
# ## 1. Python basic

# %%
### Shift+Enter key to execute or run the cell

# %%
# <- Comment ---> Not Executed by system

# %%
# Python Version check 

import sys

# %%
print(sys.version)
# Out:
# 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]

# %%
print("Hello world")
# Out:
# Hello world

# %%
print('hello world')
# Out:
# hello world

# %%
print("""Hello world""")
# Out:
# Hello world

# %%
print("100")
# Out:
# 100

# %%
ord("A")
# Out:
# 65

# %%
65+25
# Out:
# 90

# %%
ord("Z")
# Out:
# 90

# %%
chr(65)
# Out:
# 'A'

# %%
chr(90)
# Out:
# 'Z'

# %%
chr(32)
# Out:
# ' '

# %%
chr(97)
# Out:
# 'a'

# %%
chr(122)
# Out:
# 'z'

# %%
print(100)  # number: which is already defined in the system- Decimal Number value: 0-9
# Out:
# 100

# %%
print("100")
# Out:
# 100

# %%
print("100"+1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 print("100"+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(100+1)
# Out:
# 101

# %%
print("100"+"1")
# Out:
# 1001

# %%
print("Pratiksha")
# Out:
# Pratiksha

# %%
print(Pratiksha)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print(Pratiksha)
#
# NameError: name 'Pratiksha' is not defined

# %%
print('Pratiksha')
# Out:
# Pratiksha

# %% [markdown]
# ## Data Types Example

# %%
# 1. string

print("hello world")
print('Hello world')
print('1000')
print("256.23")
print('100')  # string

# 2. Integer
print(100)  # integer
print(255)
print(357)
print(7891656)


# 3. Float
print(100.23)
print(147.58)
print(100.0)


# 4. boolean

print(True)
print(False)
# Out:
# hello world
# Hello world
# 1000
# 256.23
# 100
# 100
# 255
# 357
# 7891656
# 100.23
# 147.58
# 100.0
# True
# False
